# %% [markdown]
# ## Motive:
#
#
#
# *   Find the Players below equals to 35 years and eliminate rest from the
# dataset.
# *   Which Club contains the Best Rating Players.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ## Reading the File

# %%
data = pd.read_csv("fifa.csv")

# %% [markdown]
# EDA (Exploratory Data Analysis)

# %%
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
data.shape
# Out:
# (6199, 104)

# %%
data.describe()
# Out:
#            sofifa_id          age    height_cm    weight_kg      overall  \
# count    6199.000000  6199.000000  6199.000000  6199.000000  6199.000000
# mean   207641.839652    27.125020   181.623165    76.334086    73.702533
# std     27735.624063     4.052458     6.837671     7.148960     3.931149
# min       768.000000    16.000000   156.000000    52.000000    69.000000
# 25%    192984.500000    24.000000   177.000000    71.000000    71.000000
# 50%    210951.000000    27.000000   182.000000    76.000000    73.000000
# 75%    228284.500000    30.000000   187.000000    81.000000    76.000000
# max    252685.000000    41.000000   203.000000   103.000000    94.000000
#
#          potential     value_eur       wage_eur  international_reputation  \
# count  6199.000000  6.199000e+03    6199.000000               6199.000000
# mean     76.457654  6.343226e+06   22723.665107                  1.292789
# std       4.750480  8.320605e+06   32657.871430                  0.597616
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6199 entries, 0 to 6198
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 4.9+ MB

# %%
data["lb"].isnull().sum()
# Out:
# 570

# %%
data = data.fillna(method = "ffill")

# %%
data.isnull().sum()
# Out:
# sofifa_id     0
# player_url    0
# short_name    0
# long_name     0
# age           0
#              ..
# lb            0
# lcb           0
# cb            0
# rcb           0
# rb            0
# Length: 104, dtype: int64

# %%
data.shape
# Out:
# (6199, 104)

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
data = data[data['age'] <= 35]

# %%
data.shape
# Out:
# (6082, 104)

# %% [markdown]
# Make a Dataframe in which Insert those columns which are in need.

# %%
data2 = data[['short_name','age','dob','height_cm','weight_kg','nationality','club','lwb']]

# %%
data2
# Out:
#              short_name  age         dob  height_cm  weight_kg nationality  \
# 0              L. Messi   32  1987-06-24        170         72   Argentina
# 1     Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# 2             Neymar Jr   27  1992-02-05        175         68      Brazil
# 3              J. Oblak   26  1993-01-07        188         87    Slovenia
# 4             E. Hazard   28  1991-01-07        175         74     Belgium
# ...                 ...  ...         ...        ...        ...         ...
# 6194         E. Velasco   27  1991-11-05        179         78    Colombia
# 6195         F. Zampano   25  1993-09-30        177         74       Italy
# 6196         M. Montini   27  1992-02-28        179         75       Italy
# 6197          S. Dursun   27  1991-07-12        188         79      Turkey
# 6198     I. Bel Hassani   26  1992-09-16        175         72     Morocco
#
#                      club   lwb
# 0            FC Barcelona  68+2
# ...

# %%
data2.rename(columns = {'lwb':'Ratings'},inplace = True)
# Out:
# <ipython-input-60-a1229713cfc4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.rename(columns = {'lwb':'Ratings'},inplace = True)

# %%
data_max_rating = data2.query('Ratings == Ratings.max()')

# %%
data_max_rating
# Out:
#    short_name  age         dob  height_cm  weight_kg nationality     club  \
# 15   N. Kanté   28  1991-03-29        168         72      France  Chelsea
#
#    Ratings
# 15    85+3

# %%
data2
# Out:
#              short_name  age         dob  height_cm  weight_kg nationality  \
# 0              L. Messi   32  1987-06-24        170         72   Argentina
# 1     Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# 2             Neymar Jr   27  1992-02-05        175         68      Brazil
# 3              J. Oblak   26  1993-01-07        188         87    Slovenia
# 4             E. Hazard   28  1991-01-07        175         74     Belgium
# ...                 ...  ...         ...        ...        ...         ...
# 6194         E. Velasco   27  1991-11-05        179         78    Colombia
# 6195         F. Zampano   25  1993-09-30        177         74       Italy
# 6196         M. Montini   27  1992-02-28        179         75       Italy
# 6197          S. Dursun   27  1991-07-12        188         79      Turkey
# 6198     I. Bel Hassani   26  1992-09-16        175         72     Morocco
#
#                      club Ratings
# ...
